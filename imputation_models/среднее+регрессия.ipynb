# %%
import sklearn

# %%
import pandas as pd
import numpy as np
import json
from sklearn.impute import SimpleImputer
from sklearn.metrics import root_mean_squared_error as rmse, f1_score as f1, accuracy_score as acc, precision_score as pr, recall_score as rc
import math
import scipy
from scipy.stats import entropy

# %%
import scipy
from scipy.stats import entropy

# %%
import warnings

def fxn():
    warnings.warn("deprecated", DeprecationWarning)

with warnings.catch_warnings():
    warnings.simplefilter("ignore")
    fxn()

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
int(str(11.5555).split('.')[-1])
# Out:
# 5555

# %%
def round_ (x):
  if type(x) == int:
    return x
  elif int(str(x).split('.')[-1][0]) >=5:
    x = math.ceil(x)

  else:
    if len(int(str(x).split('.')[-1])) >= 2:
      if int(str(x).split('.')[-1][1]) >=5:
        x = math.ceil(x)
    else:
      x = math.floor(x)


  return x

# %%
round_(1)
# Out:
# 1

# %%
for i in range(1, 6):
  file_mis = '/content/drive/MyDrive/Диплом/Датасеты/данные диплом/0'+str(i)+'/data0'+str(i) +'.json'
  file_tar = '/content/drive/MyDrive/Диплом/Датасеты/данные диплом/0'+str(i)+'/data0'+str(i) +'_tar.json'

# %%
data_mis = pd.read_json(file_mis)
data_tar =  pd.read_json(file_tar)

dfm1 = pd.DataFrame(data_mis.loc[1].to_dict())
dft1 = pd.DataFrame(data_tar.loc[0].to_dict())

dfm1 = dfm1[sorted(dfm1.columns)].reset_index(drop = True)
dft1 = dft1[sorted(dfm1.columns)].reset_index(drop = True)

# %%
# imp_data = imp_mean(dfm1).reset_index()

# %%
cat_ord
# Out:
# ['gndr',
#  'marital_stat',
#  'initiative1_employer',
#  'initiative2_persona',
#  'money_what_employer',
#  'money_what_persona',
#  'money_what_free_other',
#  'is_spec_crs',
#  'profwrk',
#  'edu',
#  'change_sal',
#  'title_wrk',
#  'incm']

# %%
# pd.DataFrame(entropy(imp_data[cat_ord]), index=cat_ord).to_dict()

# %%
# imp_data[int_cols].var().to_dict()

# %%
cat_cols = ['gndr', 'marital_stat', 'initiative1_employer',
       'initiative2_persona', 'money_what_employer', 'money_what_persona',
       'money_what_free_other', 'is_spec_crs', 'profwrk']

ord_cols = ['edu', 'change_sal',
       'title_wrk', 'incm']

cat_ord = ['gndr', 'marital_stat', 'initiative1_employer',
       'initiative2_persona', 'money_what_employer', 'money_what_persona',
       'money_what_free_other', 'is_spec_crs', 'profwrk', 'edu', 'change_sal',
       'title_wrk', 'incm']

int_ord = ['agea', 'agewrk', 'fctr_succ1', 'fctr_succ2', 'fctr_succ3',
       'fctr_succ4', 'impmot1', 'impmot2', 'impmot3', 'impmot4', 'impmot5',
       'impmot6', 'impmot7', 'impmot8', 'impmot9', 'mot1', 'mot10', 'mot11',
       'mot12', 'mot13', 'mot14', 'mot2', 'mot3', 'mot4', 'mot5', 'mot6',
       'mot7', 'mot8', 'mot9', 'num_crs', 'plcwrk', 'sal', 'sat_wrk', 'edu', 'change_sal',
       'title_wrk', 'incm']

int_cols = dfm1.drop(cat_cols, axis=1).drop(ord_cols, axis=1).columns


miss_vars= ["marital_stat", "num_crs",
            "mot1", "mot2", "mot3", "mot4", "mot5", "mot6", "mot7", "mot8", "mot9", "mot10", "mot11", "mot12", "mot13", "mot14",
            "edu", "agewrk", "plcwrk", "profwrk", "change_sal", "title_wrk", "sal", "sat_wrk",
            "fctr_succ1", "fctr_succ2", "fctr_succ3", "fctr_succ4",
            "impmot1", "impmot2", "impmot3", "impmot4", "impmot5", "impmot6", "impmot7", "impmot8", "impmot9",
            "agea", "incm"]


mcar = ["marital_stat", "num_crs",
        "mot2", "mot6", "mot9", "mot10", "mot11", "mot12", "mot13",
        "agewrk", "plcwrk", "sat_wrk",
        "fctr_succ3", "fctr_succ4",
        "impmot1", "impmot4", "impmot5", "impmot8", "agea", "incm", "title_wrk"]

mar = ["mot1", "mot3", "mot4", "mot5", "mot7", "mot8", "mot14",
       "edu", "profwrk", "change_sal", "sal", "fctr_succ1",
       "fctr_succ2", "impmot2", "impmot3", "impmot6", "impmot7", "impmot9"]


mcar_cat = ['marital_stat']
mcar_ord = ['incm', 'title_wrk']
mcar_int = ['mot2', 'agea', 'mot9', 'fctr_succ4',
            'mot6', 'mot10', 'mot11', 'mot12', 'mot13',
            'impmot1', 'incm', 'impmot4', 'impmot8', 'fctr_succ3', 'agewrk',
            'plcwrk', 'sat_wrk', 'impmot5', 'num_crs']



mar_int = ['impmot2', 'impmot7', 'mot1', 'mot14', 'impmot6', 'mot7', 'mot3', 'fctr_succ2', 'impmot3', 'mot8', 'mot4', 'impmot9', 'mot5', 'sal', 'fctr_succ1']
mar_cat = ['profwrk']
mar_ord = ['edu', 'change_sal']


not_mis = ['gndr', 'initiative1_employer', 'initiative2_persona', 'is_spec_crs',
       'money_what_employer', 'money_what_free_other', 'money_what_persona']

# %%
cols = ['%', 'agea', 'agewrk', 'change_sal', 'edu', 'fctr_succ1', 'fctr_succ2',
       'fctr_succ3', 'fctr_succ4', 'gndr', 'impmot1', 'impmot2', 'impmot3',
       'impmot4', 'impmot5', 'impmot6', 'impmot7', 'impmot8', 'impmot9',
       'incm', 'initiative1_employer', 'initiative2_persona', 'is_spec_crs',
       'marital_stat', 'money_what_employer', 'money_what_free_other',
       'money_what_persona', 'mot1', 'mot10', 'mot11', 'mot12', 'mot13',
       'mot14', 'mot2', 'mot3', 'mot4', 'mot5', 'mot6', 'mot7', 'mot8', 'mot9',
       'num_crs', 'plcwrk', 'profwrk', 'sal', 'sat_wrk', 'title_wrk']


# df = pd.DataFrame(columns = cols)
df = pd.DataFrame()




cols1 = ['%', 'total_rmse', 'total_acc_ord', 'total_f1_ord', 'total_pr_ord', 'total_rc_ord', 'total_acc_cat',
        'total_f1_cat', 'total_pr_cat', 'total_rc_cat']


# df_total = pd.DataFrame(columns = cols1)
df_total = pd.DataFrame()

# %%
import time

# %% [markdown]
# # 1. Среднее

# %%
# Замена отрицательных значений на NaN

def imp_mean (data):
    cat_cols = ['gndr', 'marital_stat', 'initiative1_employer',
          'initiative2_persona', 'money_what_employer', 'money_what_persona',
          'money_what_free_other', 'is_spec_crs', 'profwrk']

    ord_cols = ['edu', 'change_sal',
          'title_wrk', 'incm']

    int_cols = data.drop(cat_cols, axis=1).drop(ord_cols, axis=1).columns

    imp_mean = SimpleImputer(missing_values=np.nan, strategy='mean')
    imp_mean.fit(data[int_cols])
    int_data = imp_mean.transform(data[int_cols])
    int_data_df = pd.DataFrame(int_data, columns=int_cols)


    imp_med = SimpleImputer(missing_values=np.nan, strategy='median')
    imp_med.fit(data[ord_cols])
    ord_data = imp_med.transform(data[ord_cols])
    or_data_df = pd.DataFrame(ord_data, columns=ord_cols)

    imp_mode = SimpleImputer(missing_values=np.nan, strategy='most_frequent')
    imp_mode.fit(data[cat_cols])
    cat_data = imp_mode.transform(data[cat_cols])
    cat_data_df = pd.DataFrame(cat_data, columns=cat_cols)
    im_data = pd.concat([int_data_df, or_data_df, cat_data_df], axis=1)

    return im_data


# Использование SimpleImputer для заполнения пропусков

# %%
df_stat = pd.DataFrame()
df_stat_total = pd.DataFrame()
df = pd.DataFrame()
df_vars = pd.DataFrame()
df_vars_full = pd.DataFrame()

for i in range(1, 6):
  print('Доля пропусков', i)
  print('--------------------------------------')
  file_mis = '/content/drive/MyDrive/Диплом/Датасеты/данные диплом/0'+str(i)+'/data0'+str(i) +'_.json'
  file_tar = '/content/drive/MyDrive/Диплом/Датасеты/данные диплом/0'+str(i)+'/data0'+str(i) +'_tar_.json'

  data_mis = pd.read_json(file_mis)
  data_tar =  pd.read_json(file_tar)

  for ind in range(data_mis.shape[0]):
    df.loc[ind, '%'] = i/10

    df_total.loc[ind, '%'] =  i/10

    dfm1 = pd.DataFrame(data_mis.loc[ind].to_dict())
    dft1 = pd.DataFrame(data_tar.loc[ind].to_dict())

    dfm1 = dfm1[sorted(dfm1.columns)]
    dft1 = dft1[sorted(dfm1.columns)].reset_index(drop = True)
    start_time = time.time()
    imp_data = imp_mean(dfm1).reset_index()
    print("--- %s seconds ---" % (time.time() - start_time))

    for var in dfm1.columns:
      # print('-------------------------', var)
      index_mis = list(map(int, dfm1[var][dfm1[var].isna()].index))
      mis_imput =  imp_data[var].loc[index_mis]
      tar_vals = dft1[var].loc[index_mis]
      if len(tar_vals) == 0:
        df[var] = 'full'
        continue
      else:
        if var in int_cols:
          error = rmse(tar_vals, mis_imput)
          df.loc[ind, var] = error
          # print(var, error)
          df_vars.loc[ind, var] = imp_data[var].var()

        if var in ord_cols:
          mis_imput = mis_imput.apply(lambda row: math.ceil(row))
          error = f1(tar_vals, mis_imput, average ='macro')
          df.loc[ind, var] = error
          # print(var, error)
          df_vars.loc[ind, var] = entropy(imp_data[var])

        if var in cat_cols:
          error = f1(tar_vals, mis_imput, average ='macro')
          df.loc[ind, var] = error
          # print(var, error)
          df_vars.loc[ind, var] = entropy(imp_data[var])

  # total metrics
    imputed_data = imp_mean(dfm1)
    im_int = imputed_data[list(set(miss_vars) & set(int_cols))]
    im_ord = imputed_data[list(set(miss_vars) & set(ord_cols))].apply(np.ceil)
    im_cat = imputed_data[list(set(miss_vars) & set(cat_cols))]
    im_cat = imputed_data[list(set(miss_vars) & set(cat_cols))]

    im_cat_mar = imputed_data[mar_cat]
    im_cat_mcar = imputed_data[mcar_cat]

    im_ord_mar = imputed_data[mar_ord]
    im_ord_mcar = imputed_data[mcar_ord]

    im_int_mar = imputed_data[mar_int]
    im_int_mcar = imputed_data[mcar_int]

    imputedvars_int = np.array(im_int)[np.array(dfm1[miss_vars][int_cols].isna())]
    imputedvars_ord = np.array(im_ord)[np.array(dfm1[miss_vars][ord_cols].isna())]
    imputedvars_cat = np.array(im_cat)[np.array(dfm1[list(set(miss_vars) & set(cat_cols))].isna())]

    mar_imputedvars_cat = np.array(im_cat_mar)[np.array(dfm1[mar_cat].isna())]
    mar_imputedvars_ord = np.ceil(np.array(im_ord_mar)[np.array(dfm1[mar_ord].isna())])
    mar_imputedvars_int = np.array(im_int_mar)[np.array(dfm1[mar_int].isna())]
    mcar_imputedvars_cat = np.array(im_cat_mcar)[np.array(dfm1[mcar_cat].isna())]
    mcar_imputedvars_ord = np.ceil(np.array(im_ord_mcar)[np.array(dfm1[mcar_ord].isna())])
    mcar_imputedvars_int = np.array(im_int_mcar)[np.array(dfm1[mcar_int].isna())]


    TargetTagsvars_int = np.array(dft1[miss_vars][int_cols])[dfm1[miss_vars][int_cols].isna()]
    TargetTagsvars_ord = np.array(dft1[miss_vars][ord_cols])[dfm1[miss_vars][ord_cols].isna()]
    TargetTagsvars_cat = np.array(dft1[list(set(miss_vars) & set(cat_cols))])[dfm1[list(set(miss_vars) & set(cat_cols))].isna()]

    mar_TargetTagsvars_cat = np.array(dft1[mar_cat])[dfm1[mar_cat].isna()]
    mar_TargetTagsvars_ord = np.array(dft1[mar_ord])[dfm1[mar_ord].isna()]
    mar_TargetTagsvars_int = np.array(dft1[mar_int])[dfm1[mar_int].isna()]
    mcar_TargetTagsvars_cat = np.array(dft1[mcar_cat])[dfm1[mcar_cat].isna()]
    mcar_TargetTagsvars_ord = np.array(dft1[mcar_ord])[dfm1[mcar_ord].isna()]
    mcar_TargetTagsvars_int = np.array(dft1[mcar_int])[dfm1[mcar_int].isna()]


    df_total.loc[ind, 'total_rmse_int'] = rmse(TargetTagsvars_int, imputedvars_int)

    # df_total.loc[ind, 'total_rmse_ord'] = rmse(TargetTagsvars_ord, imputedvars_ord )
    df_total.loc[ind, 'total_acc_ord'] = acc(TargetTagsvars_ord, imputedvars_ord )
    df_total.loc[ind, 'total_f1_ord']  = f1(TargetTagsvars_ord, imputedvars_ord, average ='macro' )
    # df_total['total_pr_ord']  = pr(TargetTagsvars_ord, imputedvars_ord, average ='macro')
    # df_total['total_rc_ord'] = rc(TargetTagsvars_ord, imputedvars_ord, average ='macro')

    df_total.loc[ind, 'total_acc_cat'] = acc(TargetTagsvars_cat, imputedvars_cat)
    df_total.loc[ind, 'total_f1_cat'] = f1(TargetTagsvars_cat, imputedvars_cat, average ='macro')
    # df_total['total_pr_cat'] = pr(TargetTagsvars_cat, imputedvars_cat, average ='macro')
    # df_total['total_rc_cat'] = rc(TargetTagsvars_cat, imputedvars_cat, average ='macro')

    #mar
    df_total.loc[ind, 'mar_f1_cat']  = f1(mar_TargetTagsvars_cat, mar_imputedvars_cat, average ='macro' )
    df_total.loc[ind, 'mar_f1_ord']  = f1(mar_TargetTagsvars_ord, mar_imputedvars_ord, average ='macro' )
    df_total.loc[ind, 'mar_rmse_int']  = rmse(mar_TargetTagsvars_int, mar_imputedvars_int)
    #mcar
    df_total.loc[ind, 'mcar_f1_cat']  = f1(mcar_TargetTagsvars_cat, mcar_imputedvars_cat, average ='macro' )
    df_total.loc[ind, 'mcar_f1_ord']  = f1(mcar_TargetTagsvars_ord, mcar_imputedvars_ord, average ='macro' )
    df_total.loc[ind, 'mcar_rmse_int']  = rmse(mcar_TargetTagsvars_int, mcar_imputedvars_int)

    if ind%20 == 0:
      print(f'Загружено {ind} из {data_mis.shape[0]}' )

    # if ind == 50: break

    df_stat = pd.concat([df_stat, df])

    df_stat_total = pd.concat([df_stat_total, df_total])

    df_vars_full = pd.concat([df_vars_full, df_vars])

    df_stat = df_stat.drop_duplicates()
    df_stat_total = df_stat_total.drop_duplicates()
    df_vars_full = df_vars_full.drop_duplicates()

  print(df_stat.shape)
  print(df_stat_total.shape)
  print(df_vars_full.shape)
# Out:
# Доля пропусков 1
# --------------------------------------
# --- 0.029639720916748047 seconds ---
# Загружено 0 из 1012
# --- 0.017368793487548828 seconds ---
# --- 0.027761220932006836 seconds ---
# --- 0.02567148208618164 seconds ---
# --- 0.02361154556274414 seconds ---
# --- 0.03281235694885254 seconds ---
# --- 0.02388310432434082 seconds ---
# --- 0.023793458938598633 seconds ---
# --- 0.023325443267822266 seconds ---
# --- 0.025206565856933594 seconds ---
# --- 0.022504806518554688 seconds ---
# --- 0.0274200439453125 seconds ---
# --- 0.024821758270263672 seconds ---
# --- 0.02858138084411621 seconds ---
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-a398b4bfceb9> in <cell line: 0>()
#      30     for var in dfm1.columns:
#      31       # print('-------------------------', var)
# ---> 32       index_mis = list(map(int, dfm1[var][dfm1[var].isna()].index))
#      33       mis_imput =  imp_data[var].loc[index_mis]
#      34       tar_vals = dft1[var].loc[index_mis]
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4073             if not is_mi and (
#    4074                 self.columns.is_unique
# -> 4075                 and key in self.columns
#    4076                 or key in self.columns.drop_duplicates(keep=False)
#    4077             ):
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in __contains__(self, key)
#    5321         return is_object_dtype(self.dtype)
#    5322
# -> 5323     def __contains__(self, key: Any) -> bool:
#    5324         """
#    5325         Return a boolean indicating whether the provided key is in the index.
#
# KeyboardInterrupt:

# %%
from google.colab import files

# %%
df_stat.to_excel('mean_stat_2.xlsx')
df_stat_total.to_excel('mean_stat_total_2.xlsx')
df_vars_full.to_excel('mean_vars_stat_2.xlsx')

# %%
files.download('mean_stat_2.xlsx')
files.download('mean_stat_total_2.xlsx')
files.download('mean_vars_stat_2.xlsx')

# %% [markdown]
# # 2. Регрессия

# %%
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LogisticRegression

cat_ord_fix = ['gndr', 'marital_stat', 'initiative1_employer',
       'initiative2_persona', 'money_what_employer', 'money_what_persona',
       'money_what_free_other', 'is_spec_crs', 'profwrk', 'edu', 'change_sal',
       'title_wrk', 'incm']

# %%
df = pd.DataFrame()
df_stat = pd.DataFrame()
df_stat_total = pd.DataFrame()
df_vars = pd.DataFrame()
df_vars_full = pd.DataFrame()


for i in range(3, 6):
  print('Доля пропусков', i)
  print('--------------------------------------')
  file_mis = '/content/drive/MyDrive/Диплом/Датасеты/данные диплом/0'+str(i)+'/data0'+str(i) +'_.json'
  file_tar = '/content/drive/MyDrive/Диплом/Датасеты/данные диплом/0'+str(i)+'/data0'+str(i) +'_tar_.json'

  data_mis = pd.read_json(file_mis)
  data_tar =  pd.read_json(file_tar)

  for ind in range(data_mis.shape[0]):
    df.loc[ind, '%'] = i/10

    df_total.loc[ind, '%'] =  i/10

    dfm1 = pd.DataFrame(data_mis.loc[ind].to_dict())
    dft1 = pd.DataFrame(data_tar.loc[ind].to_dict())

    dfm1 = dfm1[sorted(dfm1.columns)].reset_index(drop = True)
    dft1 = dft1[sorted(dfm1.columns)].reset_index(drop = True)

    start_time = time.time()


    for var in miss_vars:
      data_7 = dfm1[~dfm1[var].isna()][not_mis]
      y = dfm1[~dfm1[var].isna()][var]
      data_full = dft1[~dfm1[var].isna()].drop(var, axis=1)

      data_7_test = dfm1[dfm1[var].isna()][not_mis]
      y_test = dft1[dfm1[var].isna()][var]
      data_full_test = dft1[dfm1[var].isna()].drop(var, axis=1)

      cat_ord = ['gndr', 'marital_stat', 'initiative1_employer',
          'initiative2_persona', 'money_what_employer', 'money_what_persona',
          'money_what_free_other', 'is_spec_crs', 'profwrk', 'edu', 'change_sal',
          'title_wrk', 'incm']



      if var in int_cols:
        data_full = pd.get_dummies(data_full, dummy_na=False, columns=cat_ord, drop_first=False, dtype=int)
        data_full_test = pd.get_dummies(data_full_test, dummy_na=False, columns=cat_ord, drop_first=False, dtype=int)
        data_full_test[list(set(data_full.columns) - set(data_full_test.columns))] = 0

        data_full = data_full[sorted(data_full.columns)]
        data_full_test = data_full_test[sorted(data_full.columns)]

        # # with 7 vars
        # lr7 = LinearRegression()
        # lr7.fit(data_7, y)
        # pred7 = lr7.predict(data_7_test) # НЕ РАБОТАЕТ
        # error7 = rmse(y_test, pred7)
        # df.loc[ind, var+'_7_rmse'] = error7
        # df_vars.loc[ind, var+'_7_var'] = np.concat([pred7, y]).var()

        # with all vars
        lr_all = LinearRegression()
        lr_all.fit(data_full, y)
        pred_all = lr_all.predict(data_full_test)  # не работает выкинуть
        error_all = rmse(y_test, pred_all)
        df.loc[ind, var+'_all_rmse'] = error_all
        df_vars.loc[ind, var+'_all_var'] = np.concat([pred_all, y]).var()
        # return [error7, error_all]

      elif var in cat_ord_fix:
        cat_ord1 = list(set(cat_ord) - {var})
        data_full = pd.get_dummies(data_full, dummy_na=False, columns=cat_ord1, drop_first=False, dtype=int)
        data_full_test = pd.get_dummies(data_full_test, dummy_na=False, columns=cat_ord1, drop_first=False, dtype=int)
        data_full_test[list(set(data_full.columns) - set(data_full_test.columns))] = 0

        data_full = data_full[sorted(data_full.columns)]
        data_full_test = data_full_test[sorted(data_full.columns)]

        # # with 7 vars
        # lg7 = LogisticRegression(max_iter=1000)
        # if len(y.unique()) != 1:
        #   lg7.fit(data_7, y)
        #   lgpred7 = lg7.predict(data_7_test) # не работает выкинуть
        # else:
        #   lgpred7 = np.repeat(int(y.unique()), y_test.shape[0])
        # errorlg7_f1 = f1(y_test, lgpred7, average = 'macro')
        # errorlg7_acc = acc(y_test, lgpred7)
        # df.loc[ind, var+'_7_f1'] = errorlg7_f1
        # df.loc[ind, var+'_7_acc'] = errorlg7_acc
        # df_vars.loc[ind, var+'_7_entr'] = entropy(np.concat([lgpred7, y]))
        # with all vars
        lg_all = LogisticRegression(max_iter=1000)
        if len(y.unique()) != 1:
          lg_all.fit(data_full, y)
          lgpred_all = lg_all.predict(data_full_test)
        else:
          lgpred_all = np.repeat(int(y.unique()), y_test.shape[0])



    #     errorlg_all_f1 = f1(y_test, lgpred_all, average = 'macro')
    #     errorlg_all_acc = acc(y_test, lgpred_all)
    #     df.loc[ind, var+'_all_f1'] = errorlg_all_f1
    #     df.loc[ind, var+'_all_acc'] = errorlg_all_acc

    #     df_vars.loc[ind, var+'_all_entr'] = entropy(np.concat([lgpred_all, y]))
    print("--- %s seconds ---" % (time.time() - start_time))
    df_stat = pd.concat([df_stat, df])
    df_vars_full = pd.concat([df_vars_full, df_vars])

    # df_stat_total = pd.concat([df_stat_total, df_total])

    df_stat = df_stat.drop_duplicates()
    # df_stat_total = df_stat_total.drop_duplicates()
    df_vars_full = df_vars_full.drop_duplicates()



    print(df_stat.shape)
    print(df_vars_full.shape)
# Out:
# Доля пропусков 3
# --------------------------------------
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# --- 9.555338382720947 seconds ---
# (1, 34)
# (1, 33)
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# --- 3.02087140083313 seconds ---
# (2, 34)
# (2, 33)
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# --- 9.949235677719116 seconds ---
# (3, 34)
# (3, 33)
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# <ipython-input-16-14cb0a0d763c>:99: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   lgpred_all = np.repeat(int(y.unique()), y_test.shape[0])
# --- 2.7185587882995605 seconds ---
# (4, 34)
# (4, 33)
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-16-14cb0a0d763c> in <cell line: 0>()
#      63         # with all vars
#      64         lr_all = LinearRegression()
# ---> 65         lr_all.fit(data_full, y)
#      66         pred_all = lr_all.predict(data_full_test)  # не работает выкинуть
#      67         error_all = rmse(y_test, pred_all)
#
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py in wrapper(estimator, *args, **kwargs)
#    1387                 )
#    1388             ):
# -> 1389                 return fit_method(estimator, *args, **kwargs)
#    1390
#    1391         return wrapper
#
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_base.py in fit(self, X, y, sample_weight)
#     680             # cut-off ratio for small singular values
#     681             cond = max(X.shape) * np.finfo(X.dtype).eps
# --> 682             self.coef_, _, self.rank_, self.singular_ = linalg.lstsq(X, y, cond=cond)
#     683             self.coef_ = self.coef_.T
#     684
#
# /usr/local/lib/python3.11/dist-packages/scipy/linalg/_basic.py in lstsq(a, b, cond, overwrite_a, overwrite_b, check_finite, lapack_driver)
#    1468             if real_data:
#    1469                 lwork, iwork = _compute_lwork(lapack_lwork, m, n, nrhs, cond)
# -> 1470                 x, s, rank, info = lapack_func(a1, b1, lwork,
#    1471                                                iwork, cond, False, False)
#    1472             else:  # complex data
#
# KeyboardInterrupt:

# %%
from google.colab import files

# %%
df_stat.to_excel('regr_stat_par345_часть_2.xlsx')
df_vars_full.to_excel('regr_stat_var_part345_часть_2.xlsx')

files.download('regr_stat_par345_часть_2.xlsx')
files.download('regr_stat_var_part345_часть_2.xlsx')

# %%
# def regression (dfm1, var):
miss_vars= ["marital_stat", "num_crs",
            "mot1", "mot2", "mot3", "mot4", "mot5", "mot6", "mot7", "mot8", "mot9", "mot10", "mot11", "mot12", "mot13", "mot14",
            "edu", "agewrk", "plcwrk", "profwrk", "change_sal", "title_wrk", "sal", "sat_wrk",
            "fctr_succ1", "fctr_succ2", "fctr_succ3", "fctr_succ4",
            "impmot1", "impmot2", "impmot3", "impmot4", "impmot5", "impmot6", "impmot7", "impmot8", "impmot9",
            "agea", "incm"]



cat_ord = ['gndr', 'marital_stat', 'initiative1_employer',
    'initiative2_persona', 'money_what_employer', 'money_what_persona',
    'money_what_free_other', 'is_spec_crs', 'profwrk', 'edu', 'change_sal',
    'title_wrk', 'incm']


data_f = dfm1[~dfm1[var].isna()] # только полные наблюдения по таргету
data_7_vars = data_f.drop(miss_vars, axis=1) # только полные наблюдения по 7ми переменным по таргету
y = data_f[var] # таргет для полного
data_f = data_f.drop(var)

try:
  miss_vars.remove(var)
except ValueError:
  pass

data_t = dft1.loc[list(map(int, y.index))]
data_t = data_t.loc[:, data_t.columns != var]

data_m = dfm1[dfm1[var].isna()]
data_m = data_m.loc[:, data_m.columns != var]
y_m = dft1.loc[list(map(int, data_m.index))][var]


if var in int_cols:
  # with 7 vars
  lr7 = LinearRegression()
  lr7.fit(data_7_vars, y)
  pred7 = lr7.predict(data_m.drop(miss_vars, axis=1)) # НЕ РАБОТАЕТ
  error7 = rmse(y_m, pred7)
  df.loc[ind, var+'7_rmse'] = error7
  # with all vars
  lr_all = LinearRegression()
  lr_all.fit(data_t, y)
  pred_all = lr_all.predict(dft1.loc[list(map(int, y_m.index))].drop(var, axis=1))  # не работает выкинуть
  error_all = rmse(y_m, pred_all)
  df.loc[ind, var+'all_rmse'] = error_all
  # return [error7, error_all]

elif var in cat_ord_fix:
  data_t = pd.get_dummies(data_t, dummy_na=False, columns=cat_ord.remove(var), drop_first=False, dtype=int)



  # with 7 vars
  lg7 = LogisticRegression( max_iter=10000000000)
  lg7.fit(data_7_vars, y)
  lgpred7 = lg7.predict(data_m.drop(miss_vars, axis=1)) # не работает выкинуть
  errorlg7_f1 = f1(y_m, lgpred7, average = 'macro')
  errorlg7_acc = acc(y_m, lgpred7)
  # with all vars
  lg_all = LogisticRegression(max_iter=10000000000)
  lg_all.fit(data_t, y)
  lgpred_all = lg_all.predict(dft1.loc[list(map(int, y_m.index))].drop(var, axis=1))
  errorlg_all_f1 = f1(y_m, lgpred_all, average = 'macro')
  errorlg_all_acc = acc(y_m, lgpred_all)

  # return [errorlg7_f1, errorlg7_acc, errorlg_all_f1, errorlg_all_acc]

# %%
data_7_vars

# %%
df_stat = pd.DataFrame()
df_stat_total = pd.DataFrame()

for i in range(1, 6):
  print('Доля пропусков', i)
  print('--------------------------------------')
  file_mis = '/content/drive/MyDrive/Диплом/Датасеты/данные диплом/0'+str(i)+'/data0'+str(i) +'.json'
  file_tar = '/content/drive/MyDrive/Диплом/Датасеты/данные диплом/0'+str(i)+'/data0'+str(i) +'_tar.json'

  data_mis = pd.read_json(file_mis)
  data_tar =  pd.read_json(file_tar)

  for ind in range(data_mis.shape[0]):
    df.loc[ind, '%'] = i/10

    df_total.loc[ind, '%'] =  i/10

    dfm1 = pd.DataFrame(data_mis.loc[ind].to_dict())
    dft1 = pd.DataFrame(data_tar.loc[ind].to_dict())

    dfm1 = dfm1[sorted(dfm1.columns)]
    dft1 = dft1[sorted(dfm1.columns)].reset_index(drop = True)


    for var in dfm1:
      errors = regression(dfm1, var)

      if var not in miss_vars:
        df[var] = 'full'
        continue

      if var in cat_ord:
        df.loc[ind, var+'7_f1'] = errors[0]
        df.loc[ind, var+'7_acc'] = errors[1]
        df.loc[ind, var+'all_f1'] = errors[2]
        df.loc[ind, var+'all_acc'] = errors[3]

      else:
        df.loc[ind, var+'7_rmse'] = errors[0]
        df.loc[ind, var+'all_rmse'] = errors[0]

  # total metrics




    df_stat = pd.concat([df_stat, df])

    # df_stat_total = pd.concat([df_stat_total, df_total])

    df_stat = df_stat.drop_duplicates()
    # df_stat_total = df_stat_total.drop_duplicates()

  print(df_stat.shape)
  # print(df_stat_total.shape)

# %%
var

# %%
dfm1

# %%
for var in ['agea']:
    miss_vars= ["marital_stat", "num_crs",
            "mot1", "mot2", "mot3", "mot4", "mot5", "mot6", "mot7", "mot8", "mot9", "mot10", "mot11", "mot12", "mot13", "mot14",
            "edu", "agewrk", "plcwrk", "profwrk", "change_sal", "title_wrk", "sal", "sat_wrk",
            "fctr_succ1", "fctr_succ2", "fctr_succ3", "fctr_succ4",
            "impmot1", "impmot2", "impmot3", "impmot4", "impmot5", "impmot6", "impmot7", "impmot8", "impmot9",
            "agea", "incm"]

    cat_ord = ['gndr', 'marital_stat', 'initiative1_employer',
       'initiative2_persona', 'money_what_employer', 'money_what_persona',
       'money_what_free_other', 'is_spec_crs', 'profwrk', 'edu', 'change_sal',
       'title_wrk', 'incm']

    cat_ord_fix = ['gndr', 'marital_stat', 'initiative1_employer',
       'initiative2_persona', 'money_what_employer', 'money_what_persona',
       'money_what_free_other', 'is_spec_crs', 'profwrk', 'edu', 'change_sal',
       'title_wrk', 'incm']

    data_f = dfm1[~dfm1[var].isna()]
    data_7_vars = data_f.drop(miss_vars, axis=1)
    y = data_f[var]
    miss_vars.remove(var)

    data_t = dft1.loc[list(map(int, y.index))]
    data_t = data_t.loc[:, data_t.columns != var]

    data_m = dfm1[dfm1[var].isna()]
    data_m = data_m.loc[:, data_m.columns != var]
    y_m = dft1.loc[list(map(int, data_m.index))][var]


    if var in int_cols:
      # with 7 vars
      lr7 = LinearRegression()
      lr7.fit(data_7_vars, y)
      pred7 = lr7.predict(data_m.drop(miss_vars, axis=1))
      error7 = rmse(y_m, pred7)
      # with all vars
      lr_all = LinearRegression()
      lr_all.fit(data_t, y)
      pred_all = lr_all.predict(dft1.loc[list(map(int, y_m.index))].drop('agea', axis=1))
      error_all = rmse(y_m, pred_all)

    elif var in cat_ord_fix:
      data_t = pd.get_dummies(data_t, dummy_na=False, columns=cat_ord.remove(var), drop_first=False, dtype=int)

      # with 7 vars
      lg7 = LogisticRegression( max_iter=10000000000)
      lg7.fit(data_7_vars, y)
      lgpred7 = lg7.predict(data_m.drop(miss_vars, axis=1))
      errorlg7 = f1(y_m, lgpred7, average = 'macro')
      # with all vars
      lg_all = LogisticRegression(max_iter=10000000000)
      lg_all.fit(data_t, y)
      lgpred_all = lg_all.predict(dft1.loc[list(map(int, y_m.index))].drop('marital_stat', axis=1))
      errorlg_all = f1(y_m, lgpred_all, average = 'macro')

# %%
data_f

# %%
a = pd.DataFrame(pred_all, index=list(map(str, y_m.index)), columns=['agea'])
b = dfm1.loc[list(map(str, y.index))]['agea']

pd.concat([a, b])

# %%
X = pd.get_dummies(dft1, dummy_na=False, columns=cat_ord, drop_first=False, dtype=int)
X_mis = pd.get_dummies(dfm1, dummy_na=True, columns=cat_ord, drop_first=False, dtype=int)
X_mis[list(set(X.columns) - set(X_mis.columns))] = 0

# %%
import numpy as np
import pandas as pd
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
from sklearn.linear_model import LinearRegression
from sklearn.impute import MissingIndicator # https://scikit-learn.org/stable/modules/impute.html


im_data = dfm1[dfm1.columns]



# identify variables with missing data
missing_vars = miss_vars

# identify variables to use as predictors
predictor_vars = list(set(dfm1.columns) - set(miss_vars))

# fit regression model using Bayesian Ridge
imputer = IterativeImputer(estimator=LinearRegression())

# impute missing values
imputed_data = imputer.fit_transform(im_data)
# imputed_data = imputer.fit(im_data)
# imputed_data = imputer.transform(im_data, skip_complete=True)

# substitute imputed values for missing values
# im_data[missing_vars] = imputed_data[:, -len(missing_vars):]

im_data = pd.DataFrame(imputed_data, columns = dfm1.columns)

print(dfm1.isna().sum().sum())
print(im_data.isna().sum().sum())

# %%
im = im_data
only_im = im[pd.isna(dfm1)]
only_im_true = np.array(dft1)[np.array(pd.isna(dfm1))]
